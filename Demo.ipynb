# %%
import YTTitleSuggest

# %%
title = YTTitleSuggest.Title()
# Out:
# Please Use YTTitleSuggest.Title.set_category() to Set a Category
# Search Available Categories Using YTTitleSuggest.Title.category_list
#
# Please Use YTTitleSuggest.Title.set_keyword() to Set a Keyword
# C:\Users\dan\YTTitleSuggest\YTTitleSuggest.py:58: DtypeWarning: Columns (21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv('Data/data.csv', keep_default_na=False)

# %%
title.category_list
# Out:
# ['News & Politics',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Travel & Events',
#  'People & Blogs',
#  'Film & Animation',
#  'Education',
#  'Sports',
#  'Pets & Animals',
#  'Music',
#  'Gaming',
#  'Comedy',
#  'Entertainment',
#  'Science & Technology']

# %%
title.set_keyword('space')

# %%
title.set_category('Science & Technology')

# %%
title.keyword_list()
# Out:
# ['iphone',
#  'pro',
#  'new',
#  'apple',
#  'mission',
#  'test',
#  'make',
#  'unbox',
#  'vs',
#  'galaxy',
#  'review',
#  'samsung',
#  'day',
#  'buy',
#  'max',
#  'first',
#  'google',
#  'every',
#  'launch',
#  'watch',
#  'ultra',
#  'starlink',
#  'part',
#  'io',
#  'space',
#  'get',
#  'tech',
#  'pixel',
#  'starship',
#  'gadget',
#  'event',
#  'feature',
#  'build',
#  'x',
#  'short',
#  'smarter',
#  'minute',
#  'big',
#  'game',
#  'macbook',
#  'tesla',
#  'spacex',
#  'impression',
#  'air',
#  'see',
#  'flight',
#  'deal',
#  'phone',
#  'happen',
#  'camera',
#  'explain',
#  'put',
#  'good',
#  'well',
#  'real',
#  'everything',
#  'thing',
#  'look',
#  'ever',
#  'airpod',
#  'pc',
#  'fire',
#  'official',
#  'live',
#  'fast',
#  'use',
#  'video',
#  'top',
#  'one',
#  'smart',
#  'change',
#  'go',
#  'need',
#  'reveal',
#  'series',
#  'elon',
#  'car',
#  'smartphone',
#  'electric',
#  'volcano',
#  'setup',
#  'take',
#  'weird',
# ...

# %%
title.keyword_category()
# Out:
# ['News & Politics',
#  'Howto & Style',
#  'People & Blogs',
#  'Film & Animation',
#  'Education',
#  'Music',
#  'Gaming',
#  'Comedy',
#  'Entertainment',
#  'Science & Technology']

# %%
title.show_wordCloud()

# %%
title.example_titles()
# Out:
# ['Elon Musk on how Falcon Heavy will change space travel',
#  'Astronauts Answer 50 of the Most Googled Space Questions | WIRED',
#  'Astronaut Chris Hadfield Debunks Space Myths | WIRED',
#  'SOMETHING Happened While He Was In Space..',
#  'Giant Alien-Like ARM Found At Edge Of Space...',
#  'SPACE FEED Shut Down: What Are They Hiding?',
#  'Space shuttle Endeavour anomaly - White Knight Satellite discovered?',
#  "Smoke and Fire! NASA's Space Launch System Rocket Booster Test",
#  'Northrop Grumman Cargo Launch to the Space Station from NASA Wallops',
#  'Northrop Grumman Cargo Launch to the Space Station from NASA Wallops (Launch Attempt Oct. 1, 2020)',
#  'Watch Three New Crew Members Launch to the International Space Station',
#  'Watch Three Space Travelers Return Home from the International Space Station',
#  'GPS III Space Vehicle 04 Mission',
#  "Watch NASA's SpaceX Crew-1 Mission Arrive at the International Space Station",
# ...

# %%
title.generate_keywords(positive=['space'])
# Out:
# [('crew', 0.8663740158081055),
#  ('northrop', 0.8585603833198547),
#  ('international', 0.8582544326782227),
#  ('return', 0.8536258935928345),
#  ('anomaly', 0.8388795256614685),
#  ('astronaut', 0.838796079158783),
#  ('throw', 0.8228034973144531),
#  ('three', 0.8197688460350037),
#  ('spacecraft', 0.8142940998077393),
#  ('station', 0.8134033679962158)]

# %%
title.api_key = '' ## Insert your Own OpenAI API Key
title.generate_title_GPT(positive=['space', 'JWST'])
# Out:
# Adjectives : interesting
# ChatGPT: Title: Exploring the Universe with the James Webb Space Telescope
#
# Description: In this video, we explore the wonders of space and the new era of space exploration with the soon-to-launch James Webb Space Telescope (JWST). The JWST is the most advanced space telescope ever built and is equipped with groundbreaking technologies that will enable it to see farther and clearer than ever before.
#
# We delve into the key features of the JWST, such as its large mirrors and ability to detect infrared light. We also explain how the telescope will be able to study the formation of galaxies, the birth of stars, and even search for signs of life on exoplanets.
#
# We also hear from experts and scientists who have worked on the JWST project, discussing the challenges they faced and the exciting discoveries they hope to uncover. We also get a sneak peek at some of the stunning images that will be captured by the JWST.
#
# ...
